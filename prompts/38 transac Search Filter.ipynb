# %%
from pathlib import Path
cwd = Path.cwd()

# %% [markdown]
# # <br>
# # Select Chakra docs

# %%
docs_folder = 'chakra v3 docs'
docs_item_number_in_the_prompt = '5'
docs_to_include = [
    ('Components', 'llms-components.txt'), 
    ('Styling', 'llms-styling.txt'), 
    ('Theming', 'llms-theming.txt'),
]

docs_presented = ''

for i, (title, doc) in enumerate(docs_to_include):
    path = Path(cwd, 'chakra v3 docs', doc)
    with open(path, 'r', encoding='utf-8') as file:
        f = file.read()

    doc_txt = '## ' + docs_item_number_in_the_prompt + '.' + str(i+1) + '. '
    doc_txt += title + '- below delimited by triple asterisk:\n\n***\n' + f + '\n***'
    docs_presented += doc_txt

    print('---------------------------------------------')
    print(doc_txt[:200] + '\n...')
    print()
# Out:
# ---------------------------------------------
# ## 5.1. Components- below delimited by triple asterisk:
#
# ***
# <SYSTEM>Documentation for all components in Chakra UI v3.</SYSTEM>
#
# # Accordion
#
# ```tsx
# import { Accordion, Span } from "@chakra-ui/react"
#
# ...
#
# ---------------------------------------------
# ## 5.2. Styling- below delimited by triple asterisk:
#
# ***
# <SYSTEM>Documentation for the styling system in Chakra UI v3.</SYSTEM>
#
# # Animation Styles
#
# ## Overview
#
# Animation styles allow you to define
# ...
#
# ---------------------------------------------
# ## 5.3. Theming- below delimited by triple asterisk:
#
# ***
# <SYSTEM>Documentation for theming Chakra UI v3.</SYSTEM>
#
# # Animations
#
# ## Keyframes
#
# Chakra UI supports the following keyframes out of the bo
# ...

# %% [markdown]
# # <br>
# # Files to include

# %%
path_arr = [
    Path(cwd.parent, 'backend', 'app.py'),
    Path(cwd.parent, 'backend', 'models.py'),
    Path(cwd.parent, 'backend', 'routes.py'),
    
    Path(cwd.parent, 'frontend', 'src' , 'context', 'atoms.js'),
    Path(cwd.parent, 'frontend', 'src', 'App.jsx'),
    Path(cwd.parent, 'frontend', 'src', 'components', 'ui' , 'Navbar.jsx'),
    Path(cwd.parent, 'frontend', 'src', 'components', 'ui' , 'Settings.jsx'),
    
    Path(cwd.parent, 'frontend', 'src', 'components', 'ui' , 'TransactionsManagement.jsx'),
    Path(cwd.parent, 'frontend', 'src', 'components', 'ui' , 'TransactionGrid.jsx'),
    Path(cwd.parent, 'frontend', 'src', 'components', 'ui' , 'TransactionCard.jsx'),
    Path(cwd.parent, 'frontend', 'src', 'components', 'ui' , 'CreateTransactionModal.jsx'),
    Path(cwd.parent, 'frontend', 'src', 'components', 'ui' , 'DeleteTransactionModal.jsx'),
    Path(cwd.parent, 'frontend', 'src', 'components', 'ui' , 'EditTransactionModal.jsx'),
    Path(cwd.parent, 'frontend', 'src', 'components', 'ui' , 'EditTransactionTagsModal.jsx'),
    
    Path(cwd.parent, 'frontend', 'src', 'components', 'ui' , 'TagsManagement.jsx'),
    Path(cwd.parent, 'frontend', 'src', 'components', 'ui' , 'TagsGroupsGrid.jsx'),
    Path(cwd.parent, 'frontend', 'src', 'components', 'ui' , 'TagGroupCard.jsx'),
    Path(cwd.parent, 'frontend', 'src', 'components', 'ui' , 'TagsGrid.jsx'),
    Path(cwd.parent, 'frontend', 'src', 'components', 'ui' , 'TagCard.jsx'),
    Path(cwd.parent, 'frontend', 'src', 'components', 'ui' , 'CreateTagsGroupModal.jsx'),
    Path(cwd.parent, 'frontend', 'src', 'components', 'ui' , 'DeleteTagsGroupsModal.jsx'),
    Path(cwd.parent, 'frontend', 'src', 'components', 'ui' , 'EditTagGroupModal.jsx'),
    Path(cwd.parent, 'frontend', 'src', 'components', 'ui' , 'CreateTagModal.jsx'),
    Path(cwd.parent, 'frontend', 'src', 'components', 'ui' , 'DeleteTagModal.jsx'),
    
    Path(cwd.parent, 'frontend', 'src', 'components', 'import' , 'ImportTransactions.jsx'),
    Path(cwd.parent, 'frontend', 'src', 'components', 'import' , 'ImportTransactionsStep1.jsx'),
    Path(cwd.parent, 'frontend', 'src', 'components', 'import' , 'ImportTransactionsStep2.jsx'),
    Path(cwd.parent, 'frontend', 'src', 'components', 'import' , 'ImportTransactionsStep3.jsx'),  
    Path(cwd.parent, 'frontend', 'src', 'components', 'import' , 'ConfirmImportDialog.jsx'),  
]
files_presented = {}
delimiter = "```"
files_presented = ""
for i, path in enumerate(path_arr):
    with open(path, 'r', encoding='utf-8') as file:
        f = file.read()
    if (str(path).split('.')[-1] == 'jsx') | (str(path).split('.')[-1] == 'js'):
        coment_char = '//'
    if str(path).split('.')[-1] == 'py':
        coment_char = '#'
    files_presented += delimiter + '\n' + coment_char + ' File path: ' + str(path) + '\n' + f + '\n' + delimiter + '\n\n'

# %%
print(files_presented)
# Out:
# ```
# # File path: C:\Users\mamed\Meu Drive\Code\categorization_app_new\backend\app.py
# # File path: C:\Users\mamed\Meu Drive\Code\categorization_app_new\backend\app.py
# # TODO: update this file for deployment
# from flask import Flask
# from flask_sqlalchemy import SQLAlchemy
# from flask_cors import CORS
# import os
#
# app = Flask(__name__)
# CORS(app)
#
# app.config['SQLALCHEMY_DATABASE_URI'] = 'sqlite:///transactions_db.db'
# app.config['SQLALCHEMY_TRACK_MODIFICATIONS'] = False
# app.config['JSON_SORT_KEYS'] = False
# app.config['DEBUG'] = True
# app.config['UPLOAD_FOLDER'] = os.path.join(os.path.abspath(os.path.dirname(__file__)), 'uploads/documents')
#
#
# db = SQLAlchemy(app)
#
# import routes
#
# # Create database and upload folder
# with app.app_context():
#     # print("Dropping existing tables (if any) and creating new ones...")
#     # db.drop_all() # Use with caution in production!
#     db.create_all()
#     os.makedirs(app.config['UPLOAD_FOLDER'], exist_ok=True)
#
# ...

# %% [markdown]
# ## Prompt

# %%
prompt = f"""
# 1. Context

You are working on a **React application** built with **Chakra UI v3** that allows users to manage and \
classify financial transactions.

The main layout includes a top navigation bar with the following sections:

- **Transactions** – Displays a list of financial transactions grouped by date, each group showing a date \
header and running balance.
- **Tags** – Lists all tag groups and their corresponding tags.
- **Import** – Allows users to import transactions from CSV files.
- **Settings** – Offers various configuration options for the application.

---

# 2. Problem

In the **Transactions** section, as the grid may have a lot of resgistries, it takes some \
time to the user locate a specific transaction she is looking for. Despite already having implemented \
a date sorting and filtering features, we need to garantee a smother work for the user, and come \
up with some solution to quickly locate a transaction or group of transactions.

---

# 3. Task

Create an SEARCH functionality inside **TransactionsManagement.jsx** so the user is able to search a transaction \
by keywords. The search box must be located at the **Actions Bar** and should search for any similar string \
contained in the followinf fields: 

- description
- note
- tags
- document names

---

# 4. Reference Components

Use the existing implementation enclosed in triple backticks as your starting point:

{files_presented}

---

# 5. Chakra UI v3 Documentation

Refer to the official Chakra UI v3 documentation for guidance on best practices and component usage:

{docs_presented}

---

# 6. Implementation Guidelines

- Use **only Chakra UI v3** components and idiomatic patterns.
- Do not introduce third-party libraries or custom CSS.
- Preserve the existing component structure and behavior.
- Apply clean code principles: clarity, simplicity, and maintainability.
- Use **4-space indentation** for all code.
- Where applicable, prefer Chakra’s `ref`, `Box`, or scroll container utilities for scroll tracking and restoration.

"""

# %%
prompt = f"""
# 1. Context

You are working on a **React application** built with **Chakra UI v3** that allows users to manage and \
classify financial transactions. The layout includes a top navigation bar with the following sections:

- **Transactions** – Displays a list of financial transactions grouped by date, each group showing a date \
header and running balance.
- **Tags** – Lists all tag groups and their corresponding tags.
- **Import** – Allows users to import transactions from CSV files.
- **Settings** – Offers various configuration options for the application.

---

# 2. Problem

In the **Transactions** section, the list of records can grow large, making it difficult for users to quickly locate specific transactions. Although date-based sorting and filtering are already implemented, we want to enhance the user experience by enabling faster and more flexible ways to find transactions.

---

# 3. Task

Implement a **search feature** in the `TransactionsManagement.jsx` component. This feature should allow users to search for transactions by typing **keywords** into a **search input** located in the **Actions Bar**.

The search must perform **case-insensitive partial matching** against the following transaction fields:

- `description`
- `note`
- `tags`
- `document names`

The result should dynamically filter the list of visible transactions to only show those that match the query.

---

# 4. Reference Components

Use the provided code (enclosed in triple backticks) as your starting point:

{files_presented}

---

# 5. Chakra UI v3 Documentation

Refer to the official Chakra UI v3 documentation for best practices and component usage:

{docs_presented}

---

# 6. Implementation Guidelines

- Use **only Chakra UI v3** components and idiomatic React patterns.
- Do **not** use external libraries or custom CSS.
- Maintain the existing component structure and logic flow.
- Ensure the search input is styled consistently with the rest of the UI.
- Follow **clean code principles**: prioritize clarity, simplicity, and maintainability.
- Use **4-space indentation** for all code.
- If needed, use Chakra’s `ref`, `Box`, or scroll-related utilities for scroll tracking and restoration behavior.


"""

# %% [markdown]
# # Prompt final

# %%
print(prompt)
